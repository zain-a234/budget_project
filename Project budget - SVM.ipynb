# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split


# Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder


# Models
import xgboost as xgb

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Load the dataset
saudi_pro_dataset = pd.read_csv("dataset.csv")

# %%
# Handling missing values
saudi_pro_dataset = saudi_pro_dataset.drop(['Unnamed: 0'],axis=1)
cols = ['region_project']
saudi_pro_dataset[cols] = saudi_pro_dataset[cols].fillna(saudi_pro_dataset.mode().iloc[0])
mean = ['project_area']
saudi_pro_dataset[mean] = saudi_pro_dataset[mean].fillna(saudi_pro_dataset.mean().iloc[0])
saudi_pro_dataset = saudi_pro_dataset.dropna(subset=['budget_project'])
saudi_pro_dataset = saudi_pro_dataset[saudi_pro_dataset['budget_project'] <= 86537642000]
# Out:
# C:\Users\INSPIRON\AppData\Local\Temp\ipykernel_7500\2038799687.py:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   saudi_pro_dataset[mean] = saudi_pro_dataset[mean].fillna(saudi_pro_dataset.mean().iloc[0])

# %%
# Split the dataset 

train_saudiPro, test_saudiPro = train_test_split(
    saudi_pro_dataset,
    test_size=0.2,
    train_size = 0.8,
    random_state=9000
)

# %%
X_train_saudiPro = saudi_pro_dataset.drop(['budget_project','end_month','end_year','enddate_project','start_month', 'start_year','startday_project','duration_project'],axis = 1)
y_train_saudiPro = saudi_pro_dataset['budget_project']

X_test_saudiPro = saudi_pro_dataset.drop(['budget_project','end_month','end_year','enddate_project','start_month', 'start_year','startday_project','duration_project'],axis = 1)
y_test_saudiPro = saudi_pro_dataset['budget_project']

X_train_saudiPro.shape
# Out:
# (835, 6)

# %%
# Define a function to calculate the cost for each model
def reg_cost(method, actual, preds):
    mae = mean_absolute_error(y_true=actual, y_pred=preds)
    mse = mean_squared_error(y_true=actual, y_pred=preds)
    
    print(f'Cost functions for the {method} regression is:')
    print(f'Mean Square Error: {round(mse,2)}')
    print(f'Mean Absolute Error: {round(mae,2)}\n\n')

# %%
#ordinal encoder
ordinal_saudiPro = OrdinalEncoder()

col_names_saudiPro = ["sectors","type_project","region_project","status_project"]

## Ordinal encode the column
ordinal_ls_saudiPro = ordinal_saudiPro.fit_transform(X_train_saudiPro[col_names_saudiPro])
ordinal_ls_val_saudiPro = ordinal_saudiPro.transform(X_test_saudiPro[col_names_saudiPro])

# %%
ordinal_saudiPro.categories_
# Out:
# [array([' Charity', ' Commercial', ' Educational', ' Governmental',
#         ' Health', ' Industrial', ' Residential', ' Scientific', ' Sports',
#         ' Tourist'], dtype=object),
#  array(['Charity', 'Charity, Health', 'Charity, Residential', 'Commercial',
#         'Commercial, Educational',
#         'Commercial, Educational, Charity, Residential, Health',
#         'Commercial, Educational, Governmental, Charity, Residential, Health',
#         'Commercial, Educational, Health',
#         'Commercial, Educational, Residential', 'Commercial, Governmental',
#         'Commercial, Health', 'Commercial, Industrial',
#         'Commercial, Residential', 'Commercial, Tourist',
#         'Commercial, Tourist, Governmental, Sports',
#         'Commercial, Tourist, Residential', 'Educational',
#         'Educational, Charity', 'Educational, Charity, Sports',
#         'Educational, Governmental', 'Educational, Governmental, Health',
#         'Educational, Governmental, Residential', 'Educational, Health',
#         'Educational, Residential', 'Educational, Scientific',
#         'Educational, Sports', 'Governmental', 'Governmental, Charity',
#         'Governmental, Charity, Scientific', 'Governmental, Health',
#         'Governmental, Industrial', 'Governmental, Residential',
#         'Governmental, Residential, Health', 'Governmental, Scientific',
#         'Governmental, Scientific, Health',
#         'Governmental, Scientific, Industrial', 'Governmental, Sports',
#         'Health', 'Hotel, Charity', 'Hotel, Commercial',
#         'Hotel, Commercial, Charity',
#         'Hotel, Commercial, Charity, Residential',
#         'Hotel, Commercial, Governmental, Residential',
#         'Hotel, Commercial, Residential', 'Hotel, Commercial, Tourist',
#         'Hotel, Commercial, Tourist, Residential', 'Hotel, Governmental',
#         'Hotel, Health',
#         'Hotel, Infrastructure, Commercial, Educational, Residential, Health',
#         'Hotel, Infrastructure, Commercial, Residential',
#         'Hotel, Infrastructure, Commercial, Tourist, Educational, Charity, Sports, Residential, Health',
#         'Hotel, Infrastructure, Commercial, Tourist, Educational, Governmental, Charity, Residential, Health',
#         'Hotel, Infrastructure, Commercial, Tourist, Governmental',
#         'Hotel, Infrastructure, Commercial, Tourist, Residential',
#         'Hotel, Infrastructure, Commercial, Tourist, Sports, Residential',
#         'Hotel, Infrastructure, Tourist, Educational, Governmental, Health',
#         'Hotel, Residential', 'Hotel, Tourist',
#         'Hotel, Tourist, Governmental', 'Industrial', 'Industrial, Health',
#         'Infrastructure, Charity', 'Infrastructure, Commercial',
#         'Infrastructure, Commercial, Educational, Residential, Health',
#         'Infrastructure, Commercial, Residential',
#         'Infrastructure, Commercial, Tourist',
#         'Infrastructure, Commercial, Tourist, Governmental',
#         'Infrastructure, Commercial, Tourist, Governmental, Residential, Scientific',
#         'Infrastructure, Commercial, Tourist, Residential, Health',
#         'Infrastructure, Educational, Governmental',
#         'Infrastructure, Educational, Governmental, Residential',
#         'Infrastructure, Educational, Health',
#         'Infrastructure, Governmental',
#         'Infrastructure, Governmental, Charity, Health',
#         'Infrastructure, Governmental, Charity, Residential, Health',
#         'Infrastructure, Governmental, Health',
#         'Infrastructure, Governmental, Industrial',
#         'Infrastructure, Governmental, Residential',
#         'Infrastructure, Governmental, Residential, Health',
#         'Infrastructure, Industrial', 'Infrastructure, Residential',
#         'Infrastructure, Scientific', 'Infrastructure, Tourist',
#         'Infrastructure, Tourist, Governmental',
#         'Infrastructure, Tourist, Governmental, Residential',
#         'Residential', 'Scientific', 'Sports', 'Tourist',
#         'Tourist, Educational',
#         'Tourist, Educational, Governmental, Sports',
#         'Tourist, Educational, Sports', 'Tourist, Governmental',
#         'Tourist, Governmental, Scientific',
#         'Tourist, Governmental, Sports'], dtype=object),
#  array(['ABHA', 'AD DIRIYAH', 'AL-JUBAIL', 'ALBAHA', 'ALDAMMAM',
#         'ALDHAHRAN', 'ALGHAZALA', 'ALHASSA', 'ALHENAKIYA', 'ALJAZAN',
#         'ALJAZAN, ALSHAQEEQ', 'ALJUBAIL', 'ALJUMUM', 'ALKAMIL', 'ALKHAFJI',
#         'ALKHARJ', 'ALKHOBAR', 'ALQASEEM, MECCA', 'ALTAIF', 'ALULA',
#         'ARAR',
#         'ARAR, RIYADH, BURAYDAH, HAIL, ALMUJMAA, SDAIR, JAWF, EASTERN PROVINCE',
#         'ARRASS', 'ASEER, KAHMIS MUSHAIT', 'BADR', 'BALJURASHI', 'BRAIDAH',
#         'Dumah Al Jandal', 'EASTERN PROVINCE', 'FEIFAA', 'HAFAR ALBATIN',
#         'HAIL', 'JAZAN', 'JEDDAH', 'JEDDAH, MECCA',
#         'JEDDAH, RIYADH, ALDAMAM, MUHAYIL ASEER, MECCA',
#         'KING ABDULLAH CITY', 'LAYLA', 'MADENAH',
#         'MADENAH, RIYADH, EASTERN PROVINCE', 'MECCA',
#         'MECCA, ALMUZAHMIYA, ALJMUM, ALBARABIR, RIYADH, JEDDAH',
#         'MECCA, KING ABDULLAH CITY, MEDINA, JEDDAH', 'MECCA, TAIF',
#         'MEDINA', 'NAJRAN', 'RABIGH', 'RAS ALKHAIR', 'RIYADH', 'SAKAKA',
#         'SDAIR', 'SHAQRA', 'TABUK', 'TABUK, DHUBA', 'TUBARJAL', 'TURAIF',
#         'UNAYZAH', 'WAAD ALSHAMAL', 'YANBAA'], dtype=object),
#  array(['Announced', 'Canceled', 'Complete', 'Late', 'Stumbled',
#         'Suggested projects', 'Under the construction'], dtype=object)]

# %%
X_train_saudiPro[col_names_saudiPro] = ordinal_ls_saudiPro
X_test_saudiPro[col_names_saudiPro] = ordinal_ls_val_saudiPro

X_train_saudiPro.sample(40)
# Out:
#       sectors  sector_budgets  type_project  project_area  region_project  \
# 1058      3.0   1436611825301          33.0  9.198532e+11            48.0
# 1731      6.0    709916354518          77.0  1.999999e+06            33.0
# 1092      3.0   1436611825301           6.0  9.198532e+11            36.0
# 2103      4.0    549859453510          29.0  2.000000e+06            49.0
# 827       2.0    567443636867          16.0  9.198532e+11            48.0
# 605       9.0    672120928423          13.0  1.800000e+05            30.0
# 1079      3.0   1436611825301          77.0  9.997740e+05             0.0
# 1372      3.0   1436611825301          58.0  6.000000e+04            40.0
# 1263      3.0   1436611825301          76.0  4.400000e+08            55.0
# 421       1.0   1058790791316          50.0  9.198532e+11            23.0
# 467       1.0   1058790791316          41.0  9.198532e+11            40.0
# 955       3.0   1436611825301          29.0  9.198532e+11            45.0
# 829       2.0    567443636867          16.0  9.198532e+11            36.0
# 2053      4.0    549859453510          29.0  9.820200e+04            12.0
# 1055      3.0   1436611825301          52.0  6.000000e+06            43.0
# 1985      5.0   1091256760152          59.0  9.198532e+11            36.0
# 1299      3.0   1436611825301          20.0  5.000000e+04            26.0
# 1941      5.0   1091256760152          59.0  3.000000e+05            46.0
# 1930      5.0   1091256760152          59.0  2.817800e+04            36.0
# 818       2.0    567443636867          19.0  9.198532e+11            33.0
# 958       3.0   1436611825301          26.0  1.000000e+04            26.0
# 1313      3.0   1436611825301          20.0  1.630000e+06            44.0
# 1571      6.0    709916354518          23.0  0.000000e+00            33.0
# 1997      5.0   1091256760152          79.0  9.198532e+11            39.0
# 30        1.0   1058790791316           3.0  1.200000e+04             4.0
# 1666      6.0    709916354518          43.0  9.198532e+11            33.0
# 523       9.0    672120928423          92.0  9.000000e+03             3.0
# 1618      6.0    709916354518          78.0  9.000000e+06            48.0
# 1253      3.0   1436611825301          72.0  5.000000e+06            32.0
# 2095      4.0    549859453510          10.0  2.700000e+04            48.0
# 508       9.0    672120928423          92.0  2.400000e+04            26.0
# 1874      6.0    709916354518          12.0  1.170000e+04            16.0
# 1975      5.0   1091256760152          59.0  7.700000e+04            50.0
# 1483      8.0    396629702256          36.0  3.000000e+06            33.0
# 1134      3.0   1436611825301          69.0  9.000000e+06            31.0
# 845       2.0    567443636867          19.0  9.198532e+11             6.0
# 1459      8.0    396629702256          87.0  9.198532e+11            25.0
# 2060      4.0    549859453510          29.0  2.000000e+05            56.0
# 1940      5.0   1091256760152          59.0  1.236000e+05            26.0
# 2162      4.0    549859453510          29.0  9.198532e+11            52.0
#
#       status_project
# 1058             6.0
# 1731             3.0
# 1092             3.0
# 2103             6.0
# 827              2.0
# 605              6.0
# 1079             3.0
# 1372             3.0
# 1263             6.0
# 421              0.0
# 467              0.0
# 955              0.0
# 829              2.0
# 2053             3.0
# 1055             6.0
# 1985             2.0
# 1299             3.0
# 1941             2.0
# 1930             6.0
# 818              6.0
# 958              3.0
# 1313             6.0
# 1571             4.0
# 1997             3.0
# 30               6.0
# 1666             6.0
# 523              6.0
# 1618             0.0
# 1253             6.0
# 2095             3.0
# 508              6.0
# 1874             3.0
# 1975             2.0
# 1483             2.0
# 1134             6.0
# 845              6.0
# 1459             3.0
# 2060             6.0
# 1940             6.0
# 2162             6.0

# %%
X_train_saudiPro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 835 entries, 0 to 2176
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sectors         835 non-null    float64
#  1   sector_budgets  835 non-null    int64
#  2   type_project    835 non-null    float64
#  3   project_area    835 non-null    float64
#  4   region_project  835 non-null    float64
#  5   status_project  835 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 45.7 KB

# %%
X_train_saudiPro.shape
# Out:
# (835, 6)

# %%
scaler_saudiPro = StandardScaler()

## Fit & transform data.
X_train_saudiPro_sc = scaler_saudiPro.fit_transform(X_train_saudiPro)
X_test_saudiPro_sc = scaler_saudiPro.transform(X_test_saudiPro)

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

reg_forest = RandomForestRegressor(n_estimators = 10, random_state = 0, criterion = 'squared_error')
reg_forest.fit(X_train_saudiPro_sc, y_train_saudiPro)

preds_forest = reg_forest.predict(X_test_saudiPro_sc)
mean_absolute_error(y_true=y_test_saudiPro, y_pred=preds_forest)
# Out:
# 991374043.9535304

# %%
# Save the model
import pickle
filename_RF = 'saudi_projects_regression_RF.pkl'
pickle.dump(reg_forest, open(filename_RF, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename_RF, 'rb'))
result_saudiPro = loaded_model.score(X_test_saudiPro_sc, y_test_saudiPro)
print(result_saudiPro)
# Out:
# 0.9104971863733573

# %%
X_test_saudiPro_sc
# Out:
# array([[-1.27972782,  0.27808702, -1.48840716, -0.70657652, -1.83024486,
#          1.38025705],
#        [-1.27972782,  0.27808702, -1.16756903, -0.70657649,  0.98492705,
#         -0.70009428],
#        [-1.27972782,  0.27808702, -0.20505463, -0.70657653,  0.02520935,
#          1.38025705],
#        ...,
#        [-0.05336279, -1.06860613,  0.36532427, -0.70657285,  0.72900233,
#         -0.18000645],
#        [-0.05336279, -1.06860613,  0.22272955, -0.70656546,  0.72900233,
#          1.38025705],
#        [-0.05336279, -1.06860613, -1.23886639, -0.70657647, -1.0624707 ,
#         -0.18000645]])

# %%
#################################################

# %%
# SVR
from sklearn.svm import SVR
reg_svr = SVR(kernel = 'linear')
reg_svr.fit(X_train_saudiPro_sc, y_train_saudiPro)

preds_svr = reg_svr.predict(X_test_saudiPro_sc)
mean_absolute_error(y_true=y_test_saudiPro, y_pred=preds_svr)
# Out:
# 3085830004.047136

# %%
# Save the model
import pickle
filename_SVM = 'saudi_projects_regression_SVM.pkl'
pickle.dump(reg_svr, open(filename_SVM, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename_SVM, 'rb'))
result_saudiPro = loaded_model.score(X_test_saudiPro_sc, y_test_saudiPro)
print(result_saudiPro)
# Out:
# -0.10157225065668163
